# %%
import numpy as np
import PIL 
import matplotlib.pyplot as plt
import pathlib
import os
import re
import cv2
import xml.etree.ElementTree as et

from keras.preprocessing.image import load_img

# %%
def walk_in_path(_path):
    if not os.path.exists(_path): return False
    
    for root, dirs, files in os.walk(_path, topdown=False):
       # for name in files:
          # print(os.path.join("file name:", root, name))
       for name in dirs:
          print(os.path.join("dir name:", root, name))

# %%
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', str(text)) ]

# %%
def convert_dir_to_list(base_path, class_path="white-leaf-disease/", files_path="images/*"):
    data_dir = pathlib.Path(base_path)
    sample_list = list(data_dir.glob(class_path + files_path))
    sample_list = sorted(sample_list, key=natural_keys)
    
    return sample_list

# %%
# function to extract bounding boxes from an annotation file
def extract_boxes(filename):
    # load and parse the file
    tree = et.parse(filename)
    # get the root of the document
    root = tree.getroot()
    # extract each bounding box
    boxes = list()
    for box in root.findall('.//bndbox'):
        xmin = int(box.find('xmin').text)
        ymin = int(box.find('ymin').text)
        xmax = int(box.find('xmax').text)
        ymax = int(box.find('ymax').text)
        coors = [xmin, ymin, xmax, ymax]
        boxes.append(coors)
    # extract image dimensions
    width = int(root.find('.//size/width').text)
    height = int(root.find('.//size/height').text)
    
    return boxes, width, height

# %%
dataset_path = "/Users/earthzaa/Downloads/Dataset/"
class_path = "white-leaf-disease/"

train_sample_list = convert_dir_to_list(base_path=dataset_path, class_path=class_path, files_path="images/*")

# %%
image_width = 256
image_height = 256

raw_image = train_sample_list[11]
image = load_img(raw_image)
image = image.resize((image_width, image_height))
image_data = np.asarray(image)

plt.figure(figsize=(10, 10))
plt.imshow(image_data)

# %%
xml_sample_list = convert_dir_to_list(base_path=dataset_path, class_path=class_path, files_path="annotations/*")
for xml_file in xml_sample_list[:1]:
    tree = et.parse(xml_file)
    root = tree.getroot()
    
    boxes, w, h = extract_boxes(xml_file)
    print(boxes, w, h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7748e4fe687e> in <module>
#       4     root = tree.getroot()
#       5
# ----> 6     boxes, w, h = extract_boxes(xml_file)
#       7     print(boxes, w, h)
#
# <ipython-input-5-1e0d1909d287> in extract_boxes(filename)
#       2 def extract_boxes(filename):
#       3     # load and parse the file
# ----> 4     tree = ElementTree.parse(filename)
#       5     # get the root of the document
#       6     root = tree.getroot()
#
# NameError: name 'ElementTree' is not defined
